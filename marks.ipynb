# %%
import pandas as pd
import numpy as np

# %%
marks = pd.read_csv('https://raw.githubusercontent.com/mateuszrusin/ml-filmweb-score/master/oceny.csv')
marks.head(10)
# Out:
#        ID                   Tytuł polski  \
# 0  810167                          Joker
# 1  796158            Podły, okrutny, zły
# 2  753119  Prosta historia o morderstwie
# 3  797600             Ciemno, prawie noc
# 4  460220        Wyznania zakupoholiczki
# 5  825221              W cieniu księżyca
# 6  830386                  The Wolf Hour
# 7  824402                             Ma
# 8  838822        Between Two Ferns: Film
# 9  807159             Słodki koniec dnia
#
#                              Tytuł oryginalny  Rok produkcji Ulubione Ocena  \
# 0                                         NaN           2019      NaN     7
# 1  Extremely Wicked, Shockingly Evil and Vile           2019      NaN     6
# 2                                         NaN           2016      NaN     3
# 3                                         NaN           2019      NaN     2
# 4                 Confessions of a Shopaholic           2009      NaN     3
# 5                   In the Shadow of the Moon           2019      NaN     5
# 6                                         NaN           2019      NaN     4
# 7                                         NaN           2019      NaN     4
# 8                Between Two Ferns: The Movie           2019      NaN     6
# 9                                         NaN           2019      NaN     5
#
#    Komentarz        Kraj produkcji                           Gatunek  \
# 0        NaN           Kanada, USA           Dramat, Kryminał, Akcja
# 1        NaN                   USA  Biograficzny, Kryminał, Thriller
# 2        NaN                Polska                Kryminał, Thriller
# 3        NaN                Polska                Kryminał, Thriller
# 4        NaN                   USA                      Komedia rom.
# 5        NaN                   USA                  Thriller, Sci-Fi
# 6        NaN  USA, Wielka Brytania                          Thriller
# 7        NaN                   USA                            Horror
# 8        NaN                   USA                           Komedia
# 9        NaN                Polska                            Dramat
#
#          Data
# 0  2019-10-11
# 1   2019-10-6
# 2   2019-10-5
# 3   2019-10-5
# 4   2019-10-4
# 5   2019-10-2
# 6   2019-10-2
# 7   2019-9-30
# 8   2019-9-24
# 9   2019-9-24

# %%
marks['Tytuł oryginalny']=marks['Tytuł oryginalny'].fillna(marks['Tytuł polski']);
marks.head(100)
# Out:
#         ID                                       Tytuł polski  \
# 0   810167                                              Joker
# 1   796158                                Podły, okrutny, zły
# 2   753119                      Prosta historia o morderstwie
# 3   797600                                 Ciemno, prawie noc
# 4   460220                            Wyznania zakupoholiczki
# 5   825221                                  W cieniu księżyca
# 6   830386                                      The Wolf Hour
# 7   824402                                                 Ma
# 8   838822                            Between Two Ferns: Film
# 9   807159                                 Słodki koniec dnia
# 10  785552                             X-Men: Mroczna Phoenix
# 11  786702                                         Król polki
# 12  118439                           Dick i Jane: Niezły ubaw
# 13  812781                            Śmierć nadejdzie dziś 2
# 14  774799                           Ingrid wyrusza na zachód
# 15   30907                       Jay i Cichy Bob kontratakują
# 16  793838                                     To: Rozdział 2
# 17  782923                                    Zły Samarytanin
# 18  811261                                              Greta
# 19  720753                         Godzilla II: Król potworów
# 20      37                                         Desperatki
# 21  800273                                    Projekt Koliber
# 22  796540                            Bajecznie bogaci Azjaci
# 23   88838                                         Kaliber 45
# 24  790359                                            Hellboy
# 25  794201                                           Piercing
# 26  416984                   The Hurt Locker. W pułapce wojny
# 27    7967                                            Na fali
# 28  209978  Zabójstwo Jesse'ego Jamesa przez tchórzliwego ...
# 29  795456                                              Clara
# ..     ...                                                ...
# 70  811263                                          Oskarżona
# 71  714149                Han Solo: Gwiezdne wojny - historie
# 72  737374                                            Arizona
# 73  678278                                         Po wypadku
# 74  781969                                      Tragedy Girls
# 75  601499                                              Wstyd
# 76  433913                                               2012
# 77  804174                        Niebieski ptak w moim sercu
# 78  806243                                    Rysa na ścianie
# 79  253995                                                 21
# 80  744026                                    Zachowaj spokój
# 81  118195                                      Trudne słówka
# 82  757712                                         Powiązania
# 83  797361                                  Zwierzęta Ameryki
# 84  726490                                     Kapitan Marvel
# 85    5846                                           Gliniarz
# 86  771870                           Zniknięcie Sidneya Halla
# 87   11843                                       Wściekłe psy
# 88  258442                                           Red Road
# 89  806360                                           SuperFly
# 90  465839                              Śmierć nadejdzie dziś
# 91  775006                              Tajemnice Silver Lake
# 92  752098                                    Wciąż cię widzę
# 93  809630                                         Green Book
# 94  775228                              Nigdy cię tu nie było
# 95  807561                     Czarne bractwo. BlacKkKlansman
# 96  782196                                  Pierwszy człowiek
# 97   10746                                          Obietnica
# 98  820784                                       Wysokie loty
# 99  808691                                     Velvet Buzzsaw
#
#                                      Tytuł oryginalny  Rok produkcji Ulubione  \
# 0                                               Joker           2019      NaN
# 1          Extremely Wicked, Shockingly Evil and Vile           2019      NaN
# 2                       Prosta historia o morderstwie           2016      NaN
# 3                                  Ciemno, prawie noc           2019      NaN
# 4                         Confessions of a Shopaholic           2009      NaN
# 5                           In the Shadow of the Moon           2019      NaN
# 6                                       The Wolf Hour           2019      NaN
# 7                                                  Ma           2019      NaN
# 8                        Between Two Ferns: The Movie           2019      NaN
# 9                                  Słodki koniec dnia           2019      NaN
# 10                                       Dark Phoenix           2019      NaN
# 11                                     The Polka King           2017      NaN
# 12                             Fun with Dick and Jane           2005      NaN
# 13                                 Happy Death Day 2U           2019      NaN
# 14                                   Ingrid Goes West           2017      NaN
# 15                     Jay and Silent Bob Strike Back           2001      NaN
# 16                                    It: Chapter Two           2019      NaN
# 17                                      Bad Samaritan           2018      NaN
# 18                                              Greta           2018      NaN
# 19                     Godzilla: King of the Monsters           2019      NaN
# 20                                         Set It Off           1996      NaN
# 21                            The Hummingbird Project           2018      NaN
# 22                                  Crazy Rich Asians           2018      NaN
# 23                                                .45           2006      NaN
# 24                                            Hellboy           2019      NaN
# 25                                           Piercing           2018      NaN
# 26                                    The Hurt Locker           2008      NaN
# 27                                        Point Break           1991      NaN
# 28  The Assassination of Jesse James by the Coward...           2007      NaN
# 29                                              Clara           2018      NaN
# ..                                                ...            ...      ...
# 70                                            Acusada           2018      NaN
# 71                            Solo: A Star Wars Story           2018      NaN
# 72                                            Arizona           2018      NaN
# 73                                              After           2012      NaN
# 74                                      Tragedy Girls           2017      NaN
# 75                                              Shame           2011      NaN
# 76                                               2012           2009      NaN
# 77                             A Bluebird in My Heart           2018      NaN
# 78                                Las grietas de Jara           2017      NaN
# 79                                                 21           2008      NaN
# 80                                    Please Stand By           2017      NaN
# 81                                          Spanglish           2004      NaN
# 82                                       Entanglement           2017      NaN
# 83                                   American Animals           2018      NaN
# 84                                     Captain Marvel           2019      NaN
# 85                                                Cop           1988      NaN
# 86                                        Sidney Hall           2017      NaN
# 87                                     Reservoir Dogs           1992      NaN
# 88                                           Red Road           2006      NaN
# 89                                           SuperFly           2018      NaN
# 90                                    Happy Death Day           2017      NaN
# 91                              Under the Silver Lake           2018      NaN
# 92                                    I Still See You           2018      NaN
# 93                                         Green Book           2018      NaN
# 94                         You Were Never Really Here           2017      NaN
# 95                                     BlacKkKlansman           2018      NaN
# 96                                          First Man           2018      NaN
# 97                                         The Pledge           2001      NaN
# 98                                   High Flying Bird           2019      NaN
# 99                                     Velvet Buzzsaw           2019      NaN
#
#          Ocena  Komentarz                  Kraj produkcji  \
# 0            7        NaN                     Kanada, USA
# 1            6        NaN                             USA
# 2            3        NaN                          Polska
# 3            2        NaN                          Polska
# 4            3        NaN                             USA
# 5            5        NaN                             USA
# 6            4        NaN            USA, Wielka Brytania
# 7            4        NaN                             USA
# 8            6        NaN                             USA
# 9            5        NaN                          Polska
# 10           6        NaN                             USA
# 11           6        NaN                             USA
# 12           6        NaN                             USA
# 13           6        NaN                             USA
# 14           6        NaN                             USA
# 15           7        NaN                             USA
# 16           6        NaN                     Kanada, USA
# 17           5        NaN                             USA
# 18           4        NaN                   Irlandia, USA
# 19           2        NaN                    Japonia, USA
# 20           6        NaN                             USA
# 21           5        NaN                          Kanada
# 22           4        NaN                             USA
# 23           3        NaN                             USA
# 24           5        NaN  USA, Wielka Brytania, Bułgaria
# 25           3        NaN                             USA
# 26           7        NaN                             USA
# 27           7        NaN                             USA
# 28           7        NaN    Kanada, USA, Wielka Brytania
# 29           5        NaN                     Kanada, USA
# ..         ...        ...                             ...
# 70           7        NaN               Argentyna, Meksyk
# 71           4        NaN                             USA
# 72           7        NaN                             USA
# 73           5        NaN                             USA
# 74           5        NaN                             USA
# 75           5        NaN                 Wielka Brytania
# 76           5        NaN                     Kanada, USA
# 77           7        NaN                         Francja
# 78           3        NaN            Argentyna, Hiszpania
# 79           5        NaN                             USA
# 80           6        NaN                             USA
# 81           6        NaN                             USA
# 82           6        NaN                          Kanada
# 83           7        NaN                             USA
# 84           5        NaN                  Australia, USA
# 85           5        NaN                             USA
# 86           6        NaN                             USA
# 87  brak oceny        NaN                             USA
# 88           5        NaN          Dania, Wielka Brytania
# 89           4        NaN                             USA
# 90           4        NaN                             USA
# 91           4        NaN                             USA
# 92           5        NaN                             USA
# 93           7        NaN                             USA
# 94           5        NaN   Francja, USA, Wielka Brytania
# 95           5        NaN                             USA
# 96           5        NaN                    Japonia, USA
# 97           7        NaN                             USA
# 98           5        NaN                             USA
# 99           4        NaN                             USA
#
#                              Gatunek        Data
# 0            Dramat, Kryminał, Akcja  2019-10-11
# 1   Biograficzny, Kryminał, Thriller   2019-10-6
# 2                 Kryminał, Thriller   2019-10-5
# 3                 Kryminał, Thriller   2019-10-5
# 4                       Komedia rom.   2019-10-4
# 5                   Thriller, Sci-Fi   2019-10-2
# 6                           Thriller   2019-10-2
# 7                             Horror   2019-9-30
# 8                            Komedia   2019-9-24
# 9                             Dramat   2019-9-24
# 10                     Akcja, Sci-Fi   2019-9-22
# 11                           Komedia   2019-9-22
# 12                Komedia kryminalna   2019-9-17
# 13                   Horror, Komedia   2019-9-16
# 14                   Dramat, Komedia   2019-9-15
# 15                           Komedia   2019-9-15
# 16                            Horror   2019-9-11
# 17                          Thriller   2019-8-29
# 18                          Thriller   2019-8-26
# 19                     Akcja, Sci-Fi   2019-8-26
# 20      Dramat, Sensacyjny, Thriller   2019-8-24
# 21                          Thriller   2019-8-21
# 22                           Komedia   2019-8-15
# 23                  Dramat, Thriller   2019-8-15
# 24                    Fantasy, Akcja   2019-8-14
# 25                          Thriller   2019-8-12
# 26                   Dramat, Wojenny    2019-8-8
# 27                        Sensacyjny    2019-8-8
# 28     Biograficzny, Dramat, Western    2019-8-5
# 29                    Romans, Sci-Fi    2019-8-5
# ..                               ...         ...
# 70                Kryminał, Thriller   2019-3-24
# 71                Przygodowy, Sci-Fi   2019-3-22
# 72                           Komedia   2019-3-20
# 73                            Horror   2019-3-19
# 74                   Horror, Komedia   2019-3-19
# 75                            Dramat   2019-3-16
# 76            Sci-Fi, Katastroficzny   2019-3-16
# 77                            Dramat   2019-3-15
# 78                          Thriller   2019-3-14
# 79                          Kryminał   2019-3-14
# 80                   Dramat, Komedia   2019-3-13
# 81           Dramat, Komedia, Romans   2019-3-13
# 82           Dramat, Komedia, Romans   2019-3-13
# 83                  Dramat, Kryminał   2019-3-13
# 84                     Akcja, Sci-Fi   2019-3-10
# 85        Dramat, Kryminał, Thriller    2019-3-9
# 86                            Dramat    2019-3-9
# 87             Thriller, Gangsterski    2019-3-9
# 88                            Dramat    2019-3-8
# 89         Kryminał, Thriller, Akcja    2019-3-5
# 90                            Horror    2019-3-3
# 91                          Kryminał    2019-3-2
# 92                          Thriller   2019-2-12
# 93                   Dramat, Komedia   2019-2-11
# 94                  Dramat, Thriller   2019-2-10
# 95    Biograficzny, Dramat, Kryminał   2019-2-10
# 96              Biograficzny, Dramat   2019-2-10
# 97                  Dramat, Kryminał    2019-2-9
# 98                  Dramat, Sportowy    2019-2-9
# 99                            Horror    2019-2-7
#
# [100 rows x 10 columns]

# %%
def firstCountry(x):
    x['FirstCountry']=[ y[0:y.find(',')]  if y.find(',')>0 else y for y in x['Kraj produkcji'] ]
    
    
firstCountry(marks)
marks.head()
# Out:
#        ID                   Tytuł polski  \
# 0  810167                          Joker
# 1  796158            Podły, okrutny, zły
# 2  753119  Prosta historia o morderstwie
# 3  797600             Ciemno, prawie noc
# 4  460220        Wyznania zakupoholiczki
#
#                              Tytuł oryginalny  Rok produkcji Ulubione Ocena  \
# 0                                       Joker           2019      NaN     7
# 1  Extremely Wicked, Shockingly Evil and Vile           2019      NaN     6
# 2               Prosta historia o morderstwie           2016      NaN     3
# 3                          Ciemno, prawie noc           2019      NaN     2
# 4                 Confessions of a Shopaholic           2009      NaN     3
#
#    Komentarz Kraj produkcji                           Gatunek        Data  \
# 0        NaN    Kanada, USA           Dramat, Kryminał, Akcja  2019-10-11
# 1        NaN            USA  Biograficzny, Kryminał, Thriller   2019-10-6
# 2        NaN         Polska                Kryminał, Thriller   2019-10-5
# 3        NaN         Polska                Kryminał, Thriller   2019-10-5
# 4        NaN            USA                      Komedia rom.   2019-10-4
#
#   FirstCountry
# 0       Kanada
# 1          USA
# 2       Polska
# 3       Polska
# 4          USA

# %%
mean_val = lambda x: x.mean()
converter = lambda x:  1 if x == 'USA'  else  0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
marks.dtypes
# Out:
# ID                    int64
# Tytuł polski         object
# Tytuł oryginalny     object
# Rok produkcji         int64
# Ulubione             object
# Ocena                object
# Komentarz           float64
# Kraj produkcji       object
# Gatunek              object
# Data                 object
# FirstCountry         object
# dtype: object

# %%
marks_Oceny=marks[marks['Ocena']!='brak oceny']
marks_Oceny['Ocena']=marks_Oceny['Ocena'].astype(int)
# Out:
# /home/krzysztof/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
marks_Oceny['isUSA']= marks_Oceny['FirstCountry'].apply(converter)
marks_Oceny.head()
# Out:
# /home/krzysztof/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#        ID                   Tytuł polski  \
# 0  810167                          Joker
# 1  796158            Podły, okrutny, zły
# 2  753119  Prosta historia o morderstwie
# 3  797600             Ciemno, prawie noc
# 4  460220        Wyznania zakupoholiczki
#
#                              Tytuł oryginalny  Rok produkcji Ulubione  Ocena  \
# 0                                       Joker           2019      NaN      7
# 1  Extremely Wicked, Shockingly Evil and Vile           2019      NaN      6
# 2               Prosta historia o morderstwie           2016      NaN      3
# 3                          Ciemno, prawie noc           2019      NaN      2
# 4                 Confessions of a Shopaholic           2009      NaN      3
#
#    Komentarz Kraj produkcji                           Gatunek        Data  \
# 0        NaN    Kanada, USA           Dramat, Kryminał, Akcja  2019-10-11
# 1        NaN            USA  Biograficzny, Kryminał, Thriller   2019-10-6
# 2        NaN         Polska                Kryminał, Thriller   2019-10-5
# 3        NaN         Polska                Kryminał, Thriller   2019-10-5
# 4        NaN            USA                      Komedia rom.   2019-10-4
#
#   FirstCountry  isUSA
# 0       Kanada      0
# 1          USA      1
# 2       Polska      0
# 3       Polska      0
# 4          USA      1

# %%
country_dict= lambda x: 'USA' if x == 1 else 'Other'

# %%
a = marks_Oceny[['isUSA','Ocena']].groupby('isUSA').hist(alpha=0.4,by=marks_Oceny.isUSA.apply(country_dict))

# %%
marks_Oceny[['Gatunek','Ocena']].groupby('Gatunek').hist(alpha=0.2, by =marks_Oceny.Gatunek)
# Out:
# /home/krzysztof/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# Gatunek
# Akcja                                               AxesSubplot(0.1,0.15;0.8x0.75)
# Akcja, Komedia kryminalna                           AxesSubplot(0.1,0.15;0.8x0.75)
# Akcja, Sci-Fi                                       AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Dramat                                    AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Dramat, Komedia                           AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Dramat, Sci-Fi                            AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Familijny, Akcja                          AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Familijny, Komedia                        AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Familijny, Przygodowy                     AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Komedia                                   AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Komedia, Przygodowy                       AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Przygodowy                                AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Thriller, Romans                          AxesSubplot(0.1,0.15;0.8x0.75)
# Animacja, Thriller, Sci-Fi                          AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny                                        AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dokumentalny, Muzyczny                AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat                                AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat historyczny                    AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat sądowy                         AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Komedia                       AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Kostiumowy                    AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Kryminał                      AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Muzyczny                      AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Polityczny                    AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Przygodowy                    AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Psychologiczny                AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Sportowy                      AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Western                       AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Dramat, Wojenny                       AxesSubplot(0.1,0.15;0.8x0.75)
# Biograficzny, Gangsterski                           AxesSubplot(0.1,0.15;0.8x0.75)
#                                                                  ...
# Przygodowy, Dramat historyczny                      AxesSubplot(0.1,0.15;0.8x0.75)
# Przygodowy, Komedia rom.                            AxesSubplot(0.1,0.15;0.8x0.75)
# Przygodowy, Romans                                  AxesSubplot(0.1,0.15;0.8x0.75)
# Przygodowy, Sci-Fi                                  AxesSubplot(0.1,0.15;0.8x0.75)
# Przygodowy, Thriller                                AxesSubplot(0.1,0.15;0.8x0.75)
# Romans                                              AxesSubplot(0.1,0.15;0.8x0.75)
# Romans, Sci-Fi                                      AxesSubplot(0.1,0.15;0.8x0.75)
# Sci-Fi                                              AxesSubplot(0.1,0.15;0.8x0.75)
# Sci-Fi, Katastroficzny                              AxesSubplot(0.1,0.15;0.8x0.75)
# Sensacyjny                                          AxesSubplot(0.1,0.15;0.8x0.75)
# Sensacyjny, Sci-Fi                                  AxesSubplot(0.1,0.15;0.8x0.75)
# Sensacyjny, Thriller                                AxesSubplot(0.1,0.15;0.8x0.75)
# Sensacyjny, Wojenny                                 AxesSubplot(0.1,0.15;0.8x0.75)
# Surrealistyczny, Komedia                            AxesSubplot(0.1,0.15;0.8x0.75)
# Surrealistyczny, Thriller, Sci-Fi                   AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller                                            AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Akcja                                     AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Akcja, Psychologiczny, Krótkometrażowy    AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Akcja, Sci-Fi                             AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Dramat historyczny                        AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Dramat sądowy                             AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Komedia kryminalna                        AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Psychologiczny                            AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Romans, Sci-Fi                            AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Sci-Fi                                    AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Szpiegowski                               AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Wojenny                                   AxesSubplot(0.1,0.15;0.8x0.75)
# Thriller, Wojenny, Psychologiczny                   AxesSubplot(0.1,0.15;0.8x0.75)
# Western                                             AxesSubplot(0.1,0.15;0.8x0.75)
# Wojenny                                             AxesSubplot(0.1,0.15;0.8x0.75)
# Length: 173, dtype: object

# %%
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f45c9ecf1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f45c9e9c0b8>]],
#       dtype=object)
